# %% [markdown]
# # Imports and Agents Initialization

# %%
import json

# %%
# setup ollama to run llm locally
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
# run ollama in background to pull a model
def run_ollama_in_background():
  import threading
  import subprocess
  import time

  def ollama_serve():
      subprocess.Popen(["ollama", "serve"])

  thread = threading.Thread(target=ollama_serve)
  thread.start()
  time.sleep(5)

run_ollama_in_background()

# %%
# pull models
# !ollama pull gemma3
# !ollama pull llava
# !ollama pull phi3
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest
# pulling aeda25e63ebd:   1% ▕▏  38 MB/3.3 GB                  pulling manifest
# pulling aeda25e63ebd:   2% ▕▏  70 MB/3.3 GB                  pulling manifest
# pulling aeda25e63ebd:   4% ▕▏ 120 MB/3.3 GB                  pulling manifest
# pulling aeda25e63ebd:   4% ▕▏ 134 MB/3.3 GB                  pulling manifest
# pulling aeda25e63ebd:   5% ▕▏ 178 MB/3.3 GB                  pulling manifest
# pulling aeda25e63ebd:   7% ▕▏ 219 MB/3.3 GB                  pulling manifest
# pulling aeda25e63ebd:   7% ▕▏ 241 MB/3.3 GB                  pulling manifest
# pulling aeda25e63ebd:   8% ▕▏ 280 MB/3.3 GB                  pulling manifest
# pulling aeda25e63ebd:  10% ▕▏ 329 MB/3.3 GB                  pulling manifest
# pulling aeda25e63ebd:  11% ▕▏ 355 MB/3.3 GB                  pulling manifest
# pulling aeda25e63ebd:  12% ▕▏ 399 MB/3.3 GB  385 MB/s      7spulling manifest
# pulling aeda25e63ebd:  14% ▕▏ 455 MB/3.3 GB  385 MB/s      7spulling manifest
# pulling aeda25e63ebd:  14% ▕▏ 467 MB/3.3 GB  385 MB/s      7spulling manifest
# pulling aeda25e63ebd:  15% ▕▏ 494 MB/3.3 GB  385 MB/s      7spulling manifest
# pulling aeda25e63ebd:  16% ▕▏ 537 MB/3.3 GB  385 MB/s      7spulling manifest
# pulling aeda25e63ebd:  16% ▕▏ 548 MB/3.3 GB  385 MB/s      7spulling manifest
# pulling aeda25e63ebd:  18% ▕▏ 586 MB/3.3 GB  385 MB/s      7spulling manifest
# pulling aeda25e63ebd:  19% ▕▏ 621 MB/3.3 GB  385 MB/s      7spulling manifest
# pulling aeda25e63ebd:  19% ▕▏ 627 MB/3.3 GB  385 MB/s      7spulling manifest
# pulling aeda25e63ebd:  19% ▕▏ 649 MB/3.3 GB  385 MB/s      6spulling manifest
# pulling aeda25e63ebd:  20% ▕▏ 682 MB/3.3 GB  334 MB/s      7spulling manifest
# pulling aeda25e63ebd:  20% ▕▏ 684 MB/3.3 GB  334 MB/s      7spulling manifest
# pulling aeda25e63ebd:  21% ▕▏ 717 MB/3.3 GB  334 MB/s      7spulling manifest
# pulling aeda25e63ebd:  22% ▕▏ 749 MB/3.3 GB  334 MB/s      7spulling manifest
# pulling aeda25e63ebd:  23% ▕▏ 752 MB/3.3 GB  334 MB/s      7spulling manifest
# pulling aeda25e63ebd:  23% ▕▏ 753 MB/3.3 GB  334 MB/s      7spulling manifest
# pulling aeda25e63ebd:  23% ▕▏ 754 MB/3.3 GB  334 MB/s      7spulling manifest
# pulling aeda25e63ebd:  23% ▕▏ 754 MB/3.3 GB  334 MB/s      7spulling manifest
# pulling aeda25e63ebd:  23% ▕▏ 755 MB/3.3 GB  334 MB/s      7spulling manifest
# pulling aeda25e63ebd:  23% ▕▏ 756 MB/3.3 GB  334 MB/s      7spulling manifest
# pulling aeda25e63ebd:  23% ▕▏ 757 MB/3.3 GB  247 MB/s     10spulling manifest
# pulling aeda25e63ebd:  23% ▕▏ 758 MB/3.3 GB  247 MB/s     10spulling manifest
# pulling aeda25e63ebd:  23% ▕▏ 758 MB/3.3 GB  247 MB/s     10spulling manifest
# pulling aeda25e63ebd:  23% ▕▏ 759 MB/3.3 GB  247 MB/s     10spulling manifest
# pulling aeda25e63ebd:  23% ▕▏ 759 MB/3.3 GB  247 MB/s     10spulling manifest
# pulling aeda25e63ebd:  23% ▕▏ 759 MB/3.3 GB  247 MB/s     10spulling manifest
# pulling aeda25e63ebd:  23% ▕▏ 760 MB/3.3 GB  247 MB/s     10spulling manifest
# pulling aeda25e63ebd:  23% ▕▏ 760 MB/3.3 GB  247 MB/s     10spulling manifest
# pulling aeda25e63ebd:  23% ▕▏ 761 MB/3.3 GB  247 MB/s     10spulling manifest
# pulling aeda25e63ebd:  23% ▕▏ 761 MB/3.3 GB  247 MB/s     10spulling manifest
# pulling aeda25e63ebd:  23% ▕▏ 761 MB/3.3 GB  247 MB/s     10spulling manifest
# pulling aeda25e63ebd:  23% ▕▏ 762 MB/3.3 GB  186 MB/s     13spulling manifest
# pulling aeda25e63ebd:  23% ▕▏ 762 MB/3.3 GB  186 MB/s     13spulling manifest
# pulling aeda25e63ebd:  23% ▕▏ 762 MB/3.3 GB  186 MB/s     13spulling manifest
# pulling aeda25e63ebd:  24% ▕▏ 787 MB/3.3 GB  186 MB/s     13spulling manifest
# pulling aeda25e63ebd:  26% ▕▏ 856 MB/3.3 GB  186 MB/s     13spulling manifest
# pulling aeda25e63ebd:  26% ▕▏ 881 MB/3.3 GB  186 MB/s     13spulling manifest
# pulling aeda25e63ebd:  27% ▕▏ 913 MB/3.3 GB  186 MB/s     12spulling manifest
# pulling aeda25e63ebd:  28% ▕▏ 932 MB/3.3 GB  186 MB/s     12spulling manifest
# pulling aeda25e63ebd:  29% ▕▏ 957 MB/3.3 GB  186 MB/s     12spulling manifest
# pulling aeda25e63ebd:  30% ▕▏ 993 MB/3.3 GB  186 MB/s     12spulling manifest
# pulling aeda25e63ebd:  31% ▕▏ 1.0 GB/3.3 GB  201 MB/s     11spulling manifest
# pulling aeda25e63ebd:  32% ▕▏ 1.1 GB/3.3 GB  201 MB/s     11spulling manifest
# pulling aeda25e63ebd:  33% ▕▏ 1.1 GB/3.3 GB  201 MB/s     11spulling manifest
# pulling aeda25e63ebd:  34% ▕▏ 1.1 GB/3.3 GB  201 MB/s     10spulling manifest
# pulling aeda25e63ebd:  35% ▕▏ 1.2 GB/3.3 GB  201 MB/s     10spulling manifest
# pulling aeda25e63ebd:  37% ▕▏ 1.2 GB/3.3 GB  201 MB/s     10spulling manifest
# pulling aeda25e63ebd:  38% ▕▏ 1.3 GB/3.3 GB  201 MB/s     10spulling manifest
# pulling aeda25e63ebd:  38% ▕▏ 1.3 GB/3.3 GB  201 MB/s     10spulling manifest
# pulling aeda25e63ebd:  39% ▕▏ 1.3 GB/3.3 GB  201 MB/s     10spulling manifest
# pulling aeda25e63ebd:  39% ▕▏ 1.3 GB/3.3 GB  201 MB/s     10spulling manifest
# pulling aeda25e63ebd:  40% ▕▏ 1.3 GB/3.3 GB  221 MB/s      9spulling manifest
# pulling aeda25e63ebd:  41% ▕▏ 1.4 GB/3.3 GB  221 MB/s      8spulling manifest
# pulling aeda25e63ebd:  42% ▕▏ 1.4 GB/3.3 GB  221 MB/s      8spulling manifest
# pulling aeda25e63ebd:  43% ▕▏ 1.4 GB/3.3 GB  221 MB/s      8spulling manifest
# pulling aeda25e63ebd:  43% ▕▏ 1.4 GB/3.3 GB  221 MB/s      8spulling manifest
# pulling aeda25e63ebd:  43% ▕▏ 1.4 GB/3.3 GB  221 MB/s      8spulling manifest
# pulling aeda25e63ebd:  43% ▕▏ 1.4 GB/3.3 GB  221 MB/s      8spulling manifest
# pulling aeda25e63ebd:  43% ▕▏ 1.4 GB/3.3 GB  221 MB/s      8spulling manifest
# pulling aeda25e63ebd:  43% ▕▏ 1.4 GB/3.3 GB  221 MB/s      8spulling manifest
# pulling aeda25e63ebd:  43% ▕▏ 1.4 GB/3.3 GB  221 MB/s      8spulling manifest
# pulling aeda25e63ebd:  43% ▕▏ 1.4 GB/3.3 GB  202 MB/s      9spulling manifest
# pulling aeda25e63ebd:  43% ▕▏ 1.4 GB/3.3 GB  202 MB/s      9spulling manifest
# pulling aeda25e63ebd:  43% ▕▏ 1.4 GB/3.3 GB  202 MB/s      9spulling manifest
# pulling aeda25e63ebd:  43% ▕▏ 1.4 GB/3.3 GB  202 MB/s      9spulling manifest
# pulling aeda25e63ebd:  43% ▕▏ 1.4 GB/3.3 GB  202 MB/s      9spulling manifest
# pulling aeda25e63ebd:  43% ▕▏ 1.4 GB/3.3 GB  202 MB/s      9spulling manifest
# pulling aeda25e63ebd:  43% ▕▏ 1.4 GB/3.3 GB  202 MB/s      9spulling manifest
# pulling aeda25e63ebd:  43% ▕▏ 1.4 GB/3.3 GB  202 MB/s      9spulling manifest
# pulling aeda25e63ebd:  43% ▕▏ 1.4 GB/3.3 GB  202 MB/s      9spulling manifest
# pulling aeda25e63ebd:  43% ▕▏ 1.4 GB/3.3 GB  202 MB/s      9spulling manifest
# pulling aeda25e63ebd:  43% ▕▏ 1.4 GB/3.3 GB  178 MB/s     10spulling manifest
# pulling aeda25e63ebd:  43% ▕▏ 1.4 GB/3.3 GB  178 MB/s     10spulling manifest
# pulling aeda25e63ebd:  43% ▕▏ 1.4 GB/3.3 GB  178 MB/s     10spulling manifest
# pulling aeda25e63ebd:  43% ▕▏ 1.4 GB/3.3 GB  178 MB/s     10spulling manifest
# pulling aeda25e63ebd:  44% ▕▏ 1.5 GB/3.3 GB  178 MB/s     10spulling manifest
# pulling aeda25e63ebd:  44% ▕▏ 1.5 GB/3.3 GB  178 MB/s     10spulling manifest
# pulling aeda25e63ebd:  46% ▕▏ 1.5 GB/3.3 GB  178 MB/s     10spulling manifest
# pulling aeda25e63ebd:  47% ▕▏ 1.6 GB/3.3 GB  178 MB/s      9spulling manifest
# pulling aeda25e63ebd:  47% ▕▏ 1.6 GB/3.3 GB  178 MB/s      9spulling manifest
# pulling aeda25e63ebd:  48% ▕▏ 1.6 GB/3.3 GB  178 MB/s      9spulling manifest
# pulling aeda25e63ebd:  49% ▕▏ 1.6 GB/3.3 GB  178 MB/s      9spulling manifest
# pulling aeda25e63ebd:  49% ▕▏ 1.6 GB/3.3 GB  180 MB/s      9spulling manifest
# pulling aeda25e63ebd:  50% ▕▏ 1.7 GB/3.3 GB  180 MB/s      9spulling manifest
# pulling aeda25e63ebd:  50% ▕▏ 1.7 GB/3.3 GB  180 MB/s      9spulling manifest
# pulling aeda25e63ebd:  51% ▕▏ 1.7 GB/3.3 GB  180 MB/s      9spulling manifest
# pulling aeda25e63ebd:  51% ▕▏ 1.7 GB/3.3 GB  180 MB/s      9spulling manifest
# pulling aeda25e63ebd:  52% ▕▏ 1.7 GB/3.3 GB  180 MB/s      8spulling manifest
# pulling aeda25e63ebd:  53% ▕▏ 1.8 GB/3.3 GB  180 MB/s      8spulling manifest
# pulling aeda25e63ebd:  53% ▕▏ 1.8 GB/3.3 GB  180 MB/s      8spulling manifest
# pulling aeda25e63ebd:  54% ▕▏ 1.8 GB/3.3 GB  180 MB/s      8spulling manifest
# pulling aeda25e63ebd:  55% ▕▏ 1.8 GB/3.3 GB  180 MB/s      8spulling manifest
# pulling aeda25e63ebd:  55% ▕▏ 1.8 GB/3.3 GB  160 MB/s      9spulling manifest
# pulling aeda25e63ebd:  56% ▕▏ 1.9 GB/3.3 GB  160 MB/s      9spulling manifest
# pulling aeda25e63ebd:  57% ▕▏ 1.9 GB/3.3 GB  160 MB/s      9spulling manifest
# pulling aeda25e63ebd:  57% ▕▏ 1.9 GB/3.3 GB  160 MB/s      8spulling manifest
# pulling aeda25e63ebd:  58% ▕▏ 1.9 GB/3.3 GB  160 MB/s      8spulling manifest
# pulling aeda25e63ebd:  59% ▕▏ 2.0 GB/3.3 GB  160 MB/s      8spulling manifest
# pulling aeda25e63ebd:  60% ▕▏ 2.0 GB/3.3 GB  160 MB/s      8spulling manifest
# pulling aeda25e63ebd:  61% ▕▏ 2.0 GB/3.3 GB  160 MB/s      8spulling manifest
# pulling aeda25e63ebd:  61% ▕▏ 2.1 GB/3.3 GB  160 MB/s      8spulling manifest
# pulling aeda25e63ebd:  63% ▕▏ 2.1 GB/3.3 GB  160 MB/s      7spulling manifest
# pulling aeda25e63ebd:  63% ▕▏ 2.1 GB/3.3 GB  157 MB/s      7spulling manifest
# pulling aeda25e63ebd:  64% ▕▏ 2.1 GB/3.3 GB  157 MB/s      7spulling manifest
# pulling aeda25e63ebd:  65% ▕▏ 2.2 GB/3.3 GB  157 MB/s      7spulling manifest
# pulling aeda25e63ebd:  65% ▕▏ 2.2 GB/3.3 GB  157 MB/s      7spulling manifest
# pulling aeda25e63ebd:  66% ▕▏ 2.2 GB/3.3 GB  157 MB/s      7spulling manifest
# pulling aeda25e63ebd:  67% ▕▏ 2.2 GB/3.3 GB  157 MB/s      7spulling manifest
# pulling aeda25e63ebd:  68% ▕▏ 2.3 GB/3.3 GB  157 MB/s      6spulling manifest
# pulling aeda25e63ebd:  68% ▕▏ 2.3 GB/3.3 GB  157 MB/s      6spulling manifest
# pulling aeda25e63ebd:  69% ▕▏ 2.3 GB/3.3 GB  157 MB/s      6spulling manifest
# pulling aeda25e63ebd:  70% ▕▏ 2.3 GB/3.3 GB  157 MB/s      6spulling manifest
# pulling aeda25e63ebd:  71% ▕▏ 2.4 GB/3.3 GB  178 MB/s      5spulling manifest
# pulling aeda25e63ebd:  72% ▕▏ 2.4 GB/3.3 GB  178 MB/s      5spulling manifest
# pulling aeda25e63ebd:  72% ▕▏ 2.4 GB/3.3 GB  178 MB/s      5spulling manifest
# pulling aeda25e63ebd:  73% ▕▏ 2.4 GB/3.3 GB  178 MB/s      5spulling manifest
# pulling aeda25e63ebd:  73% ▕▏ 2.4 GB/3.3 GB  178 MB/s      4spulling manifest
# pulling aeda25e63ebd:  74% ▕▏ 2.5 GB/3.3 GB  178 MB/s      4spulling manifest
# pulling aeda25e63ebd:  75% ▕▏ 2.5 GB/3.3 GB  178 MB/s      4spulling manifest
# pulling aeda25e63ebd:  76% ▕▏ 2.5 GB/3.3 GB  178 MB/s      4spulling manifest
# pulling aeda25e63ebd:  77% ▕▏ 2.6 GB/3.3 GB  178 MB/s      4spulling manifest
# pulling aeda25e63ebd:  78% ▕▏ 2.6 GB/3.3 GB  178 MB/s      4spulling manifest
# pulling aeda25e63ebd:  78% ▕▏ 2.6 GB/3.3 GB  178 MB/s      4spulling manifest
# pulling aeda25e63ebd:  79% ▕▏ 2.6 GB/3.3 GB  206 MB/s      3spulling manifest
# pulling aeda25e63ebd:  80% ▕▏ 2.7 GB/3.3 GB  206 MB/s      3spulling manifest
# pulling aeda25e63ebd:  80% ▕▏ 2.7 GB/3.3 GB  206 MB/s      3spulling manifest
# pulling aeda25e63ebd:  81% ▕▏ 2.7 GB/3.3 GB  206 MB/s      3spulling manifest
# pulling aeda25e63ebd:  82% ▕▏ 2.7 GB/3.3 GB  206 MB/s      2spulling manifest
# pulling aeda25e63ebd:  82% ▕▏ 2.8 GB/3.3 GB  206 MB/s      2spulling manifest
# pulling aeda25e63ebd:  83% ▕▏ 2.8 GB/3.3 GB  206 MB/s      2spulling manifest
# pulling aeda25e63ebd:  84% ▕▏ 2.8 GB/3.3 GB  206 MB/s      2spulling manifest
# pulling aeda25e63ebd:  85% ▕▏ 2.8 GB/3.3 GB  206 MB/s      2spulling manifest
# pulling aeda25e63ebd:  86% ▕▏ 2.9 GB/3.3 GB  206 MB/s      2spulling manifest
# pulling aeda25e63ebd:  86% ▕▏ 2.9 GB/3.3 GB  206 MB/s      2spulling manifest
# pulling aeda25e63ebd:  87% ▕▏ 2.9 GB/3.3 GB  206 MB/s      2spulling manifest
# pulling aeda25e63ebd:  88% ▕▏ 2.9 GB/3.3 GB  206 MB/s      1spulling manifest
# pulling aeda25e63ebd:  89% ▕▏ 3.0 GB/3.3 GB  206 MB/s      1spulling manifest
# pulling aeda25e63ebd:  90% ▕▏ 3.0 GB/3.3 GB  206 MB/s      1spulling manifest
# pulling aeda25e63ebd:  90% ▕▏ 3.0 GB/3.3 GB  206 MB/s      1spulling manifest
# pulling aeda25e63ebd:  91% ▕▏ 3.0 GB/3.3 GB  206 MB/s      1spulling manifest
# pulling aeda25e63ebd:  92% ▕▏ 3.1 GB/3.3 GB  206 MB/s      1spulling manifest
# pulling aeda25e63ebd:  92% ▕▏ 3.1 GB/3.3 GB  206 MB/s      1spulling manifest
# pulling aeda25e63ebd:  93% ▕▏ 3.1 GB/3.3 GB  206 MB/s      1spulling manifest
# pulling aeda25e63ebd:  94% ▕▏ 3.1 GB/3.3 GB  198 MB/s      1spulling manifest
# pulling aeda25e63ebd:  95% ▕▏ 3.2 GB/3.3 GB  198 MB/s      0spulling manifest
# pulling aeda25e63ebd:  95% ▕▏ 3.2 GB/3.3 GB  198 MB/s      0spulling manifest
# pulling aeda25e63ebd:  96% ▕▏ 3.2 GB/3.3 GB  198 MB/s      0spulling manifest
# pulling aeda25e63ebd:  97% ▕▏ 3.2 GB/3.3 GB  198 MB/s      0spulling manifest
# pulling aeda25e63ebd:  98% ▕▏ 3.3 GB/3.3 GB  198 MB/s      0spulling manifest
# pulling aeda25e63ebd:  99% ▕▏ 3.3 GB/3.3 GB  198 MB/s      0spulling manifest
# pulling aeda25e63ebd:  99% ▕▏ 3.3 GB/3.3 GB  198 MB/s      0spulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB/3.3 GB  198 MB/s      0spulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B                         pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠋ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠙ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠹ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠸ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠼ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠴ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠦ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠧ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠇ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠏ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠋ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠙ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠹ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠸ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠼ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠴ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠦ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠧ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠇ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠏ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠋ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠙ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠹ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠸ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠼ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠴ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠦ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠧ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠇ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠏ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠋ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠙ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠹ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠸ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠼ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠴ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠦ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠧ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠇ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠏ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠋ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠙ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠹ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠸ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠼ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠴ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠦ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠧ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠇ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠏ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠋ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠙ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠹ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠸ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠼ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠴ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠦ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠧ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠇ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠏ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠋ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠙ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠹ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠸ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠼ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠴ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠦ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠧ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠇ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# ...
# verifying sha256 digest ⠙ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠹ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠸ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠼ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠴ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠦ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠧ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠇ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠏ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠋ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠙ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠹ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠸ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠼ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠴ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠦ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠧ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠇ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠏ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠋ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠙ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠹ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠸ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠼ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠴ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠦ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠧ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠇ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠏ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠋ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠙ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠹ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠸ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠼ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠴ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠦ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠧ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠇ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠏ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠋ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠙ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠹ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠸ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠼ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest ⠴ pulling manifest
# pulling aeda25e63ebd: 100% ▕▏ 3.3 GB
# pulling e0a42594d802: 100% ▕▏  358 B
# pulling dd084c7d92a3: 100% ▕▏ 8.4 KB
# pulling 3116c5225075: 100% ▕▏   77 B
# pulling b6ae5839783f: 100% ▕▏  489 B
# verifying sha256 digest
# writing manifest
# success

# %%
# install python dependencies
# !pip install ollama
# !pip install groq
# Out:
# Collecting ollama
#   Downloading ollama-0.4.8-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: httpx<0.29,>=0.27 in /usr/local/lib/python3.11/dist-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from ollama) (2.11.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<0.29,>=0.27->ollama) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<0.29,>=0.27->ollama) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<0.29,>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<0.29,>=0.27->ollama) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<0.29,>=0.27->ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.9.0->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.9.0->ollama) (2.33.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.9.0->ollama) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.9.0->ollama) (0.4.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<0.29,>=0.27->ollama) (1.3.1)
# Downloading ollama-0.4.8-py3-none-any.whl (13 kB)
# Installing collected packages: ollama
# Successfully installed ollama-0.4.8
# Collecting groq
#   Downloading groq-0.23.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from groq) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from groq) (2.11.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.11/dist-packages (from groq) (4.13.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.0)
# Downloading groq-0.23.1-py3-none-any.whl (127 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.4/127.4 kB 9.0 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-0.23.1

# %%
# --- LLM Model Functions ---

def groq_deepseek_r1(messages):
    from groq import Groq
    import re
    client = Groq(api_key="API-Key")
    response = client.chat.completions.create(
        model="deepseek-r1-distill-llama-70b",
        messages=messages,
        temperature=0,
    )
    think_pattern = r"<think>(.*?)</think>"
    content_pattern = r"</think>\s*(.*)"

    # Extracting the 'thinking' content using regex
    think_match = re.search(think_pattern, response.choices[0].message.content.strip(), re.DOTALL)
    content_match = re.search(content_pattern, response.choices[0].message.content.strip(), re.DOTALL)

    # Assign variables based on regex match results
    thinking_content = think_match.group(1).strip() if think_match else None
    main_content = content_match.group(1).strip() if content_match else None
    return main_content, thinking_content

def groq_qwen_qwq(messages):
    from groq import Groq
    import re
    client = Groq(api_key="API-Key")
    response = client.chat.completions.create(
        model="qwen-qwq-32b",
        messages=messages,
        temperature=0,
    )
    think_pattern = r"<think>(.*?)</think>"
    content_pattern = r"</think>\s*(.*)"

    # Extracting the 'thinking' content using regex
    think_match = re.search(think_pattern, response.choices[0].message.content.strip(), re.DOTALL)
    content_match = re.search(content_pattern, response.choices[0].message.content.strip(), re.DOTALL)

    # Assign variables based on regex match results
    thinking_content = think_match.group(1).strip() if think_match else None
    main_content = content_match.group(1).strip() if content_match else None
    return main_content, thinking_content

def groq_llama_4scout(messages):
    from groq import Groq
    client = Groq(api_key="API-Key")
    response = client.chat.completions.create(
        model="meta-llama/llama-4-scout-17b-16e-instruct",
        messages=messages,
        temperature=0,
    )
    return response.choices[0].message.content.strip(), None

def groq_mistral_saba(messages):
    from groq import Groq
    client = Groq(api_key="API-Key")
    response = client.chat.completions.create(
        model="mistral-saba-24b",
        messages=messages,
        temperature=0,
    )
    return response.choices[0].message.content.strip(), None

def groq_llama_33versatile(messages):
    from groq import Groq
    client = Groq(api_key="API-Key")
    response = client.chat.completions.create(
        model="llama-3.3-70b-versatile",
        messages=messages,
        temperature=0,
    )
    return response.choices[0].message.content.strip(), None

def openrouter_reka(messages):
    from openai import OpenAI
    import re
    client = OpenAI(
        api_key="API-Key",
        base_url="https://openrouter.ai/api/v1"
    )
    response = client.chat.completions.create(
        model="rekaai/reka-flash-3:free",
        messages=messages,
        temperature=0
    )
    think_pattern = r"<reasoning>(.*?)</reasoning>"
    content_pattern = r"</reasoning>\s*(.*)"

    # Extracting the 'thinking' content using regex
    think_match = re.search(think_pattern, response.choices[0].message.content.strip(), re.DOTALL)
    content_match = re.search(content_pattern, response.choices[0].message.content.strip(), re.DOTALL)

    # Assign variables based on regex match results
    thinking_content = think_match.group(1).strip() if think_match else None
    main_content = content_match.group(1).strip() if content_match else None
    return main_content, thinking_content

def openrouter_maids(messages):
    from openai import OpenAI
    client = OpenAI(
        api_key="API-Key",
        base_url="https://openrouter.ai/api/v1"
    )
    response = client.chat.completions.create(
        model="microsoft/mai-ds-r1:free",
        messages=messages,
        temperature=0
    )
    return response.choices[0].message.content.strip(), None

def ollama_mistral(messages):
    from ollama import chat
    response = chat("mistral", messages=messages)
    return response["message"]["content"].strip(), None

def ollama_gemma3(messages):
    from ollama import chat
    response = chat("gemma3", messages=messages)
    return response["message"]["content"].strip(), None

def ollama_llava(messages):
    from ollama import chat
    response = chat("llava", messages=messages)
    return response["message"]["content"].strip(), None

def ollama_phi3(messages):
    from ollama import chat
    response = chat("phi3", messages=messages)
    return response["message"]["content"].strip(), None

def perplexity_sonar(messages):
    import requests
    url = "https://api.perplexity.ai/chat/completions"
    payload = {
        "model": "sonar",
        "messages": messages
    }
    headers = {
        "Authorization": "your-data",
        "Content-Type": "application/json"
    }
    response = requests.request("POST", url, json=payload, headers=headers).json()
    return response["choices"][0]["message"]["content"].strip()

def google_gemini_25flash(messages):
    from openai import OpenAI
    client = OpenAI(
        api_key="API-Key",
        base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
    )
    response = client.chat.completions.create(
        model="gemini-2.5-flash-preview-04-17",
        messages=messages,
        temperature=0
    )
    return response.choices[0].message.content.strip(), None

def x_grok_3mini(messages):
    from openai import OpenAI
    client = OpenAI(
        api_key="API-Key",
        base_url="https://api.x.ai/v1"
    )
    response = client.chat.completions.create(
        model="grok-3-mini-beta",
        messages=messages,
        temperature=0
    )
    return response.choices[0].message.content.strip(), response.choices[0].message.reasoning_content

def openai_gpt_35turbo(messages):
    from openai import OpenAI
    client = OpenAI(api_key="API-Key")
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=messages,
        temperature=0,
    )
    return response.choices[0].message.content.strip(), None

def openai_gpt4(messages):
    from openai import OpenAI
    client = OpenAI(api_key="API-Key")
    response = client.chat.completions.create(
        model="gpt-4",
        messages=messages,
        temperature=0,
    )
    return response.choices[0].message.content.strip(), None

models = {
    "groq_deepseek_r1": groq_deepseek_r1,
    "groq_qwen_qwq": groq_qwen_qwq,
    "groq_llama_4scout": groq_llama_4scout,
    "groq_llama_33versatile": groq_llama_33versatile,
    "groq_mistral_saba": groq_mistral_saba,
    "ollama_gemma3": ollama_gemma3,
    "google_gemini_25flash": google_gemini_25flash,
    "x_grok_3mini": x_grok_3mini,
    "openai_gpt4": openai_gpt4,
    "openai_gpt_35turbo": openai_gpt_35turbo,
}

# %% [markdown]
# # Main Code

# %%
# --- Request a vote on the following topic ---
def get_vote(topic, model_fn):
    messages = [
        {
            "role": "system",
            "content": "Form your own view on the topic and then respond with 'agree' or 'disagree' (one word, no extra text) to the topic"
        },
        {"role": "user", "content": topic},
    ]
    try:
        return model_fn(messages)
    except Exception as e:
        return f"error: {str(e)}", None

# %%
# --- Simulation process ---
def collect_votes(topic, num_agents=100):
    print(f"\n--- {topic} ---")
    print(f"\n--- Voting phase ---")
    print(f"Models: {models.keys()}")

    voting_result = []

    for model_name in models.keys():
        agent_votes = []

        for i in range(num_agents):

            vote, thinking = get_vote(topic, models[model_name])
            print(f"\n----- {model_name}_{i} -----")
            print(f"# Vote: {vote}")
            print(f"# Thinking: {thinking}")
            print(f"----- ---------------- -----\n")

            agent_votes.append({"agent": f"{model_name}_{i}", "vote": vote, "thinking": thinking})
            time.sleep(1)

        voting_result.append({"model": model_name, "votes": agent_votes})

    return voting_result

# %%
# --- Start voting process ---

# run ollama in background to run a model
run_ollama_in_background()

topics = [
    "Protecting the environment is the individual's responsibility.",
    "Protecting the environment is not the individual's responsibility.",
    "A study in Nature Journal states that household consumption accounts for roughly 60–70% of global greenhouse gas emissions,suggesting that protecting the environment is the individual's responsibility. Do you agree or disagree that protecting the environment is each individual’s job?",
    "Governments have the power to regulate industries and enact large-scale environmental policies. Without such systemic change, individual efforts might be negligible. Do you agree or disagree that protecting the environment is each individual’s job?",
]

results = []

if __name__ == "__main__":

    for topic in topics:
        result = {"topic": topic, "voting_result": collect_votes(topic, num_agents=10)}
        results.append(result)

        with open('individual_voting_result.json', 'w', encoding="utf-8") as f:
          json.dump(results, f, ensure_ascii=False, indent=4)
# Out:
# --- Protecting the environment is the individual's responsibility. ---
#
# --- Voting phase ---
# Models: dict_keys(['google_gemini_25flash'])
#
# ----- google_gemini_25flash_0 -----
# # Vote: disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_1 -----
# # Vote: disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_2 -----
# # Vote: disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_3 -----
# # Vote: disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_4 -----
# # Vote: disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_5 -----
# # Vote: disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_6 -----
# # Vote: disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_7 -----
# # Vote: disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_8 -----
# # Vote: disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_9 -----
# # Vote: disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# --- Protecting the environment is not the individual's responsibility. ---
#
# --- Voting phase ---
# Models: dict_keys(['google_gemini_25flash'])
#
# ----- google_gemini_25flash_0 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_1 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_2 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_3 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_4 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_5 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_6 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_7 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_8 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_9 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# --- A study in Nature Journal states that household consumption accounts for roughly 60–70% of global greenhouse gas emissions,suggesting that protecting the environment is the individual's responsibility. Do you agree or disagree that protecting the environment is each individual’s job? ---
#
# --- Voting phase ---
# Models: dict_keys(['google_gemini_25flash'])
#
# ----- google_gemini_25flash_0 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_1 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_2 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_3 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_4 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_5 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_6 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_7 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_8 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_9 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# --- Governments have the power to regulate industries and enact large-scale environmental policies. Without such systemic change, individual efforts might be negligible. Do you agree or disagree that protecting the environment is each individual’s job? ---
#
# --- Voting phase ---
# Models: dict_keys(['google_gemini_25flash'])
#
# ----- google_gemini_25flash_0 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_1 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_2 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_3 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_4 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_5 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_6 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_7 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_8 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
#
#
# ----- google_gemini_25flash_9 -----
# # Vote: Disagree
# # Thinking: None
# ----- ---------------- -----
